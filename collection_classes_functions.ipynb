# %%
import numpy as np


class Regression(self, fit_intercept = True):
    self.X
    self.y

    #def OLS(X, y):

def polynomial_features(x, p, fit_intercept=False):
    x = np.asarray(x)
    n = len(x)
    
    if fit_intercept:
        X = np.zeros((n, p + 1))
        X[:, 0] = 1 
        for i in range(1, p + 1):
            X[:, i] = x**i
    else:
        X = np.zeros((n, p))
        for i in range(p):
            X[:, i] = x**(i + 1)

    return X


#X = polynomial_features(x, 3, fit_intercept=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 import numpy as np
# ----> 4 class Regression(self):
#       5     self.X
#       6     self.y
#
# NameError: name 'self' is not defined
